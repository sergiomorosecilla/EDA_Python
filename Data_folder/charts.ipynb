# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
#Cargo el archivo csv
df_charts = pd.read_csv('./clean&merge_data.csv')

df_charts.head()
# Out:
#     age           job   marital            education  default  housing  loan  \
# 0  22.0      services    SINGLE          high.school        0        1     0
# 1  56.0    technician  DIVORCED  professional.course        0        0     0
# 2  31.0   blue-collar   MARRIED             basic.9y        0        0     0
# 3  38.0   blue-collar    SINGLE    university.degree        0        0     0
# 4  39.0  entrepreneur   MARRIED             basic.6y        0        1     0
#
#      contact  duration  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0  telephone      94.0       2.0  999.0       0.0  NONEXISTENT          -2.9
# 1   cellular     464.0       1.0    3.0       2.0      SUCCESS          -1.1
# 2   cellular     365.0       2.0  999.0       0.0  NONEXISTENT          -1.8
# 3  telephone     109.0       1.0  999.0       0.0  NONEXISTENT           1.1
# 4   cellular     265.0       2.0   16.0       1.0      SUCCESS          -3.4
#
# ...

# %%
# Defino las columnas númericas que nos ineteresan
# para los gráficos de frecuencia que mostraremos

col_num = df_charts.select_dtypes(include='number').columns
col_num
# Out:
# Index(['age', 'default', 'housing', 'loan', 'duration', 'campaign', 'pdays',
#        'previous', 'emp.var.rate', 'latitude', 'longitude', 'income',
#        'kidhome', 'teenhome', 'numwebvisitsmonth'],
#       dtype='object')

# %%
#Utilizamos un bucle for, para que nos haga todos los gráficos. Con 
#el bucle siempre podremos escalarlo a mas variables falcilmente añadiendo
#en variable creada col_num
for columna in col_num:
    plt.figure(figsize=(12, 5))

    sns.histplot(data=df_charts, x=columna, bins=20,kde=False, palette="magma")

    plt.title(f'Frecuencia de {columna}')
    plt.xlabel('')
    plt.ylabel('')
    plt.xticks(rotation=45)

    plt.show()
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_32124\1365046658.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df_charts, x=columna, bins=20,kde=False, palette="magma")
# C:\Users\sergi\AppData\Local\Temp\ipykernel_32124\1365046658.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df_charts, x=columna, bins=20,kde=False, palette="magma")
# C:\Users\sergi\AppData\Local\Temp\ipykernel_32124\1365046658.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df_charts, x=columna, bins=20,kde=False, palette="magma")
# C:\Users\sergi\AppData\Local\Temp\ipykernel_32124\1365046658.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df_charts, x=columna, bins=20,kde=False, palette="magma")
# ...

# %%
# Defino ahora las columnas categóricas para las visualizaciones de 
#frecuencias
col_cat = ['job', 'marital', 'education', 'contact', 'poutcome',
       'subscribe']

# %%
for columna in col_cat:
    plt.figure(figsize=(12, 5))

    sns.histplot(data=df_charts, x=columna, bins=20, kde=False)


    plt.title(f'Frecuencia de {columna}')
    plt.xlabel('')
    plt.ylabel('')
    plt.xticks(rotation=45)

    plt.show()

# %% [markdown]
# ## Relaciones cruzadas

# %% [markdown]
# Vamos a seleccionar una columna, en este caso va a ser `income`versus columnas numéricas para ver la correclación y el grado de `subscribe`
# (contratatación)

# %%
columna = 'income'

cols_num = df_charts.select_dtypes(include='number').columns
col_num = cols_num.drop(['income',])

# Generar gráficos de dispersión
for col in cols_num:

    plt.figure()
    sns.scatterplot(x=df_charts[col], y=df_charts[columna], hue=df_charts['subscribe'], alpha=0.5)

    plt.show()

# %% [markdown]
# Revisamos ahora con la variables categóricas

# %%
columna = 'income'

cols_cat = df_charts.select_dtypes(include='object').columns
#Elimino las que no deseamos
cols_cat = cols_cat.drop(['subscribe', 'call_date', 'nr.employed', 'id'])
cols_cat
# Out:
# Index(['job', 'marital', 'education', 'contact', 'poutcome', 'dt_customer'], dtype='object')

# %%
# Generar gráficos de dispersión
for col in cols_cat:

    plt.figure()
    sns.scatterplot(x=df_charts[col], y=df_charts[columna], hue=df_charts['subscribe'], palette="magma", alpha=0.5)
    plt.xticks(rotation=90)

    plt.show()

# %%
# Definir la variable objetivo
columna = 'subscribe'

for col in df_charts.columns:
    # Saltar la variable objetivo
    if col == columna:
        continue

    plt.figure(figsize=(10, 5))

    if col in col_num:
        sns.histplot(x=df_charts[col], hue=df_charts[columna], palette="magma", legend=True)
    elif col in col_cat:
        sns.countplot(x=df_charts[col], hue=df_charts[columna], palette="magma")

    plt.title(f"{col} vs {columna}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.tight_layout ()
    plt.show()
